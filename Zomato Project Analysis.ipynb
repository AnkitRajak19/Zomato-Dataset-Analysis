# %% [markdown]
# #Zomato Data Analysis Project

# %% [markdown]
# #To Find Out In Our Project
#
# 1.What Type Of Restaurant Do The majority of customer order frome?
#
# 2.How many votes has each type of restaturant received from customers?
#
# 3.What are the rating that the majority of restaurants have received?
#
# 4.Zomato has observed that most couples order most of their food online. What is their average spending on each order?
#
# 5.Which mode (online or offline) has received the maximum rating?
#
# 6.Which type of resturent received more offline order, so that zomato can provid
# customer with some good offers?

# %% [markdown]
# Step:-1 Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Step:-2 Create The Data Frame

# %%
df=pd.read_csv('/content/drive/MyDrive/Zomato Data/Zomato data.csv')
df
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %% [markdown]
# #Convert the data type of column-Rate

# %%
def handleRate(value):
  value=str(value).split('/')
  value=value[0];
  return float(value)

df['rate']=df['rate'].apply(handleRate)
print(df.head())
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df
# Out:
#                       name online_order book_table  rate  votes  \
# 0                    Jalsa          Yes        Yes   4.1    775
# 1           Spice Elephant          Yes         No   4.1    787
# 2          San Churro Cafe          Yes         No   3.8    918
# 3    Addhuri Udupi Bhojana           No         No   3.7     88
# 4            Grand Village           No         No   3.8    166
# ..                     ...          ...        ...   ...    ...
# 143       Melting Melodies           No         No   3.3      0
# 144        New Indraprasta           No         No   3.3      0
# 145           Anna Kuteera          Yes         No   4.0    771
# 146                 Darbar           No         No   3.0     98
# 147          Vijayalakshmi          Yes         No   3.9     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    float64
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 8.2+ KB

# %% [markdown]
# #Type Of Resturent

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
sns.countplot(x=df['listed_in(type)'])
plt.xlabel('Type Of Restaurant')
# Out:
# Text(0.5, 0, 'Type Of Restaurant')

# %% [markdown]
# #Conclusion- majority of the resturent falls in dinning category

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
grouped_data=df.groupby('listed_in(type)')['votes'].sum()
result=pd.DataFrame({'votes':grouped_data})
plt.plot(result,c='green',marker='o')
plt.xlabel('Type Of Restaurant',c='r',size=15)
plt.ylabel('Total Votes',c='r',size=15)
# Out:
# Text(0, 0.5, 'Total Votes')

# %% [markdown]
# #Conclusion- Dinning resturent has recieved maximum votes

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
plt.hist(df['rate'],bins=5)
plt.title('Rating Distribution')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #Conclusion-The majority resturants received ratings from 3.5 to 4.

# %% [markdown]
# #Average order spending by couples

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
couple_data=df['approx_cost(for two people)']
sns.countplot(x=couple_data)
# Out:
# <Axes: xlabel='approx_cost(for two people)', ylabel='count'>

# %% [markdown]
# #conclusion-the majority of couples prefer resturants with an approximatly cost of 300 RS.

# %% [markdown]
# #Which mode receives maximum rating

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
plt.figure(figsize=(6,6))
sns.boxplot(x='online_order',y='rate',data=df)
# Out:
# <Axes: xlabel='online_order', ylabel='rate'>

# %% [markdown]
# #Conclusion- Offline order received lower rating in comparison to online order

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df['online_order'],hue=df['rate'])
# Out:
# <Axes: xlabel='online_order', ylabel='count'>

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
pivot_table=df.pivot_table(index='listed_in(type)',columns='online_order',aggfunc='size',fill_value=0)
sns.heatmap(pivot_table,annot=True,cmap='YlGnBu',fmt='d')
plt.title('heatmap')
plt.xlabel('Online Order')
plt.ylabel('Type Of Restaurant')
plt.show()

# %% [markdown]
# #

# %% [markdown]
# #Conclusion: Dining restaurant primarily accept offline orders, whereas cafes primarily receive online order. This suggests that clients prefer orders in person at restauranst, but prefer online ordering at cafes.

# %%
df.head(1)
# Out:
#     name online_order book_table  rate  votes  approx_cost(for two people)  \
# 0  Jalsa          Yes        Yes   4.1    775                          800
#
#   listed_in(type)
# 0          Buffet

# %%
df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes',
#        'approx_cost(for two people)', 'listed_in(type)'],
#       dtype='object')

# %%
df[(df['online_order']=='Yes')&(df['rate']==4.1)]
# Out:
#                                             name online_order book_table  \
# 0                                          Jalsa          Yes        Yes
# 1                                 Spice Elephant          Yes         No
# 10                                  Village Café          Yes         No
# 51                              Shree Cool Point          Yes         No
# 65                                   Kabab Magic          Yes         No
# 76   Sri Guru Kottureshwara Davangere Benne Dosa          Yes         No
# 120                       Bengaluru Coffee House          Yes         No
#
#      rate  votes  approx_cost(for two people) listed_in(type)
# 0     4.1    775                          800          Buffet
# 1     4.1    787                          800          Buffet
# 10    4.1    402                          500           Cafes
# 51    4.1     28                          150          Dining
# 65    4.1   1720                          400          Dining
# ...

# %%
len(df[(df['online_order']=='Yes')&(df['rate']==4.1)])
# Out:
# 7
